# %%
import pandas as pd
df = pd.read_csv('campaign_data.csv')
df.head()
# Out:
#    Campaign_ID       Date  Ad_Type  Clicks  Impressions  Conversions  \
# 0            1  2023-10-1  Display     908         5137           28
# 1            2  2023-10-2  Display     750         5742           46
# 2            3  2023-10-3   Search     578         3993           30
# 3            4  2023-10-4   Search     643         5691           15
# 4            5  2023-10-5   Social     322         3982           40
#
#   CTR (Click-Through Rate) Conversion_Rate  Revenue_Created  Cost  \
# 0                    7.81%           3.86%              170   311
# 1                    4.00%           7.23%              646   443
# 2                    6.20%           6.13%              422   315
# 3                    9.18%           7.34%              527   242
# 4                    7.62%           6.02%              840   142
#
#                                         Owner  Likes  Dislikes
# 0  0x43FE4E014C100F4F773CD40156DFAC70657C049F    124       968
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset from the CSV file
file_path = "campaign_data.csv"
data = pd.read_csv(file_path)

# Define the features (attributes) and the target (Fraud)
features = ["Clicks", "Impressions", "Conversions", "Likes", "Dislikes"]
target = "Fraud"

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data[features], data[target], test_size=0.2, random_state=42)

# Create a Logistic Regression model
model = LogisticRegression()

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_rep)

# Now you can use the trained model to predict fraud for new data (campaigns)
new_campaign = pd.DataFrame({
    "Clicks": [250],
    "Impressions": [5000],
    "Conversions": [10],
    "Likes": [95],
    "Dislikes": [5]
})

fraud_prediction = model.predict(new_campaign)
fraud_probability = model.predict_proba(new_campaign)[:, 1]  # Probability of fraud (class 1)

print(f"Predicted Fraud (0 = Not Fraud, 1 = Fraud): {fraud_prediction[0]}")
print(f"Probability of Fraud: {fraud_probability[0]:.2f}")
# Out:
# Accuracy: 0.50
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.41      0.45       150
#            1       0.50      0.60      0.55       150
#
#     accuracy                           0.50       300
#    macro avg       0.50      0.50      0.50       300
# weighted avg       0.50      0.50      0.50       300
#
# Predicted Fraud (0 = Not Fraud, 1 = Fraud): 1
# Probability of Fraud: 0.51
